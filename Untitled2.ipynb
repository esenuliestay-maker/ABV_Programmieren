# %%
ergebnisse = [
    ("Anna Bauer",      82),
    ("Ben Schulz",      47),
    ("Clara Hoffmann",  95),
    ("Daniel Meier",    63),
    ("Elena Fischer",   55),
    ("Felix Wagner",    71),
    ("Greta Koch",      88),
    ("Hans Müller",     38),
]

# %%
for name, punkte in ergebnisse:
    if punkte >= 90:
        note = "1,0"
    elif punkte >= 75:
        note = "2.0"
    elif punkte >= 60:
        note = "3.0"
    elif punkte >= 50:
        note = "4.0"
    elif punkte < 50:
        note = "5.0"

# %%
print(name, punkte)
# Out:
# Hans Müller 38
